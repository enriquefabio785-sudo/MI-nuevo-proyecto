# %% [markdown]
# # El dilema económico cubano¿los precios o los salarios?
#
# **Primer proyecto de Ciencia de Datos 1er Año / 1er Semestre**
#
# **Autor**: Fabio Enrique Morales
#
# **Fecha**: 1/11/25-19/12/25
#
# Todos los meses ocurre lo mismo en las casas cubanas,el dinero llega y rápido nos damos cuenta que no va a alcanzar.¿La culpa es de que los productos estan carísimos o mas bien es problema de que ganamos poco?
#
# Abordaremos este asunto con datos de La Habana que muestran lo que vive toda Cuba , con datos reales que cualquier familia reconoce.Productos que compramos a los cuales solo podemos acceder en el sector no estatal debido a la escasez cada vez mas marcada de estos en la canasta familiar normada(bodega)  , precios que pagamos , salarios que recibimos y la ecuación que a fin de mes nunca cierra.

# %%
import graficas as gr
import mapas as map

# %% [markdown]
# # ¿Que alcanza para comprar con tu salario

# %%
gr.primer_grafico()

# %% [markdown]
# Imagina tu salario sobre la mesa , ahora piensa : ¿cuantos kilos de arroz podrias comprar si solo gastaras en eso? ¿Cuantos kilos de frijoles? ¿litros de aceite?
#
# Este gráfico es exactamente este cálculo.Toma 5 cosas que no fallan en la cocina cubana y calcula cuanto de cada una te llevas a casa si todo tu salario se fuera solo en esos productos.
#
# Esto es lo básico,antes de hablar de precios altos o bajos , estos números son la primera señal de alarma o de calma.

# %% [markdown]
# # ¿Cuánto cuesta lo que realmente compramos?

# %%
gr.segundo_grafico()

# %% [markdown]
# Ya sabemos cuanto podemos comprar , ahora toca ver el precio.Este gráfico utiliza nueve productos que todo el mundo conoce , desde lo imprescindible hasta esos "extras" que hacen la vida un poco más llevadera .Cada barra azul es el precio medio en pesos cubanos.
#
# La pregunta es directa ¿a cuánto sale realmente llevar un plato a la mesa del cubano?

# %% [markdown]
# # ¿Tu salario cubre lo mínimo o lo suficiente?

# %%
gr.tercer_grafico()

# %% [markdown]
# Ahora vamos a lo concreto. No compramos cosas sueltas, sino que armamos canastas. Tres niveles reales que cualquier familia reconoce:
#
# Canasta de supervivencia: Lo justo para no pasar hambre - arroz (5kg), frijoles (1.5kg), azúcar (1kg), aceite (1L), sal (0.5kg), pasta de tomate (400gr), espaguetis (1kg), detergente (500gr), jabón (2), pasta dental (1), y 10 huevos.
#
# Canasta media: Para vivir sin apuros - todo lo anterior en más cantidad, más leche en polvo (1kg), harina (1kg), café molido (284gr), papel sanitario (4 rollos), y 20 huevos.
#
# Canasta ideal: Con calidad de vida - similar a la media pero con cartón completo de huevos, buen café y champú.
#
# Observando esta gráfica , planteate la pregunta:¿tu sueldo te da para vivir o solo para sobrevivir?No es lo mismo pasar el mes comiendo arroz con sal que poder variar la comida , limpiar la casa y mantener la higiene.
#
# Fíjate donde cae la linea del salario medio . Ni siquiera llega a la barra roja. Esto da paso a la siguiente pregunta :

# %% [markdown]
# # ¿Los precios cubanos son una excepción en el mundo?

# %%
gr.cuarto_grafico()

# %% [markdown]
# Hasta ahora todo se ha representado en pesos cubanos(CUP) pero Cuba no está sola en el mundo , importamos y exportamos con otros países ¿Como se comparan nuestros precios con los de países de los cuáles importamos?
#
# Este gráfico convierte todo a dólares y compara siete productos básicos entre Cuba, México, España, Brasil y China. Cada grupito de barras horizontales es un producto, cada color un país.
#
# Entonces ¿El problema es que aqui todo es carisimo o es que ganamos una cantidad en una moneda que poco vale para comprar cosas que internacionalmente se pagan en dólares?

# %% [markdown]
# # ¿Cuánto más pagamos nosotros comparado con otros países?

# %%
gr.quinto_grafico()

# %% [markdown]
# Para terminar las comparaciones, este gráfico pone a Cuba como referencia, la linea constante es el 100% ,las barras de colores nos muestran como están los otros países respecto a nosotros
#
# Ahora la pregunta no es "cuanto cuesta en dólares, sino "cuánto más caro o barato es comparado con lo que pagamos nosotros". Si en México está al 50%, significa que alli cuesta la mitad,si en España está al 150% ahi es 50% más caro.
#
# Esto es lo que mas claridad da, nos quita el enredo de las monedas y nos da comparación directa.

# %% [markdown]
# # Mi pequeño aporte

# %%
map.mapa_colores()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# Como pueden observar este análisis tiene como objetivo sacar a la luz la fuente principal del bajo poder adquisitivo del cubano promedio en Cuba(La Habana),pero de alguna manera quería hacer un aporte para facilitar la búsqueda de productos y hacer un poco más ameno la obtención de los mismos.
#
# En el mapa se muestra la ubicación de las 30 mypimes abordadas en el proyecto y cada una está representada con un color , variando de rojo a verde teniendo en cuenta menor y mayor disponibilidad de productos respectivamente

# %% [markdown]
# # La conclusión que duele pero hay que decir
#
# Cinco gráficos, cinco miradas a un mismo problema, el primero nos enseñó que con el salario se compra poco ,el segundo que los precios son altos para nuestro bolsillo y el tercero nos dejo claro que ni para lo más básico alcanza.
#
# Los últimos dos nos dieron perspectiva: nuestros precios son comparables internacionalmente asi que la fuente del problema no es la inflación de los productos.
#
# La verdad que sale de los números:
#
# El problema tiene dos lados, pero uno pesa mucho más: los precios en Cuba no son los más altos del mundo en dólares, pero los salarios sí son demasiado bajos para comprar lo básico ,el desbalance no está tanto en que las cosas cuesten el doble, sino en el salario medio de cada cubano.
#
# Dicho mas claro: básicamente lo que ganamos no se conecta con lo que necesitamos al menos para cubrir las necesidades básicas.
#
# En resumen final: La escasez de la familia cubana viene sobre todo de salarios que no llegan al costo de vida. Los precios altos en algunos escenarios ,empeoran las cosas.
